# %%
import os
import pandas as pd
from pprint import pprint

token = os.environ['EC3_KEY']

# %%
#Getting EPD records example
from ec3 import EC3epds
ec3_epds = EC3epds(bearer_token=token, ssl_verify=False)

epd_param_dict = {"product_classes":{"EC3":"Concrete >> ReadyMix"}, "concrete_compressive_strength_at_28d__target":"3000 psi", "lightweight":True, "applicable_in":["NAFTA"]}
ec3_epds.max_records = 10 #default max records is 100
ec3_epds.only_valid = False #You can set this to False if you want to also return expired EPDs
epd_records = ec3_epds.get_epds(params=epd_param_dict)

pprint(epd_records[0])
# Out:
# {'also_shown_in': [],
#  'applicable_in': ['001'],
#  'best_practice': '396.6323207 kgCO2e',
#  'biogenic_embodied_carbon_z': 0.11237437430304116,
#  'box_id': '295275087696',
#  'category': {'allows_any_declared_unit': False,
#               'beta_only': False,
#               'category_statistics_warning': False,
#               'created_on': '2018-06-26T00:55:48.206869Z',
#               'declared_unit': '1 m3',
#               'default_distance': '51.49888 km',
#               'default_transport_mode': 'concrete mixer truck',
#               'description': 'Concretes sprayed on a target',
#               'display_name': 'Shotcrete',
#               'draft': False,
#               'facility_type': 'PLANT',
#               'generic_material': False,
#               'hide_service_life': True,
#               'id': 'cca4044f110c43aab149b8387c28f749',
#               'includes_b1_stage': False,
#               'lcia_uncertainty': 0.03,
#               'mass_per_declared_unit': '2400 kg',
#               'massless': False,
#               'masterformat': '03 37 13 Shotcrete',
#               'name': 'Shotcrete',
#               'obsolete': False,
#               'openepd': 'Concrete >> Shotcrete',
#               'openepd_name': 'Concrete >> Shotcrete',
#               'pct10_gwp': '352.0070146 kgCO2e',
#               'pct20_gwp': '384.1567594 kgCO2e',
#               'pct30_gwp': '403.0011297 kgCO2e',
#               'pct40_gwp': '421.7378415 kgCO2e',
#               'pct50_gwp': '446.8083755 kgCO2e',
#               'pct60_gwp': '466.6432115 kgCO2e',
#               'pct70_gwp': '488.7357902 kgCO2e',
#               'pct80_gwp': '523.8582089 kgCO2e',
#               'pct90_gwp': '570.5854707 kgCO2e',
#               'requires_mass_per_declared_unit': False,
#               'short_name': 'Shotcrete',
#               'short_service_life_disclaimer': False,
#               'unspsc': '30110000',
#               'updated_on': '2023-01-08T07:00:38.077670Z',
#               'use_stored_carbon': 'ABSENT'},
#  'cementitious': {'fly_ash': 0.0, 'ggbs': 0.0},
#  'concrete_air_entrain': False,
#  'concrete_co2_entrain': False,
#  'concrete_compressive_strength_28d': '27.57902917 MPa',
#  'concrete_self_consolidating': False,
#  'confirmable_fields': [],
#  'confirmed_fields': [],
#  'conservative_estimate': '479.7960505 kgCO2e',
#  'cqd_sync_unlocked': True,
#  'created_on': '2018-06-21T18:23:10.884915Z',
#  'date_of_issue': '2016-10-27',
#  'date_validity_ends': '2018-09-15',
#  'declared_unit': '1 m3',
#  'density': '2400 kg/m³',
#  'description': 'LIGHTWEIGHT SHOTCRETE',
#  'developer': {'email': 'laurel.mcewen@climateearth.com',
#                'name': 'Laurel McEwen',
#                'org': {'address': '137 Park Place, Richmond, CA 94801',
#                        'address_line': '137 Park Place',
#                        'admin_district': 'CA',
#                        'admin_district2': 'Contra Costa',
#                        'alt_names': ['Climate Earth, Inc.', 'Climate Earth'],
#                        'country': 'US',
#                        'cqd_sync_unlocked': True,
#                        'created_on': '2018-09-07T12:26:19.155179Z',
#                        'email_extensions': ['climateearth.com'],
#                        'enterprise': True,
#                        'id': '5d43c53212c848d9861a81a4bbd626b2',
#                        'image': 'https://cqddatastore.blob.core.windows.net/cqd/images/7ce922a6-8120-420c-9ca9-cd4ff793d90e',
#                        'latitude': 37.9266,
#                        'legal_name': 'Climate Earth',
#                        'locality': 'Richmond',
#                        'location': {'country': 'United States',
#                                     'countryCode': 'US',
#                                     'countryCodeISO3': 'USA',
#                                     'countrySecondarySubdivision': 'Contra '
#                                                                    'Costa',
#                                     'countrySubdivision': 'CA',
#                                     'countrySubdivisionName': 'California',
#                                     'extendedPostalCode': '948013895',
#                                     'freeformAddress': '137 Park Place, '
#                                                        'Richmond, CA 94801',
#                                     'localName': 'Richmond',
#                                     'municipality': 'Richmond',
#                                     'postalCode': '94801',
#                                     'streetName': 'Park Place',
#                                     'streetNumber': '137'},
#                        'longitude': -122.38494,
#                        'name': 'Climate Earth',
#                        'org_type': 'Private',
#                        'original_ec3_link': 'https://buildingtransparency.org/ec3/organizations/5d43c53212c848d9861a81a4bbd626b2',
#                        'password_login_allowed': True,
#                        'pilot_all_employees': False,
#                        'postal_code': '94801',
#                        'primary_activity_builder': False,
#                        'primary_activity_design': False,
#                        'primary_activity_digitization_qa': False,
#                        'primary_activity_education': False,
#                        'primary_activity_forest_practices_certification': False,
#                        'primary_activity_industry_association': False,
#                        'primary_activity_manufacturer': False,
#                        'primary_activity_operator': True,
#                        'primary_activity_other': False,
#                        'primary_activity_owner': False,
#                        'primary_activity_performance_standards_issuer': False,
#                        'primary_activity_sustainability_consulting': True,
#                        'primary_activity_verifier': True,
#                        'updated_on': '2021-04-20T03:01:07.468332Z',
#                        'web_domain': 'climateearth.com',
#                        'website': 'http://www.climateearth.com'}},
#  'doc': 'cqd.io/e/ec3ae51gdy',
#  'epd_degraded': False,
#  'excluded': False,
#  'externally_verified': True,
#  'gwp': '439 kgCO2e',
#  'gwp_per_category_declared_unit': '439 kgCO2e',
#  'gwp_per_kg': '0.1829166667 kgCO2e',
#  'gwp_z': 0.11237437430304116,
#  'id': '38e0f454364e4b988c491a0f939651ff',
#  'image': 'https://cqddatastore.blob.core.windows.net/cqd/images/d09ed90be05f495b9668ce665660ddb0.png',
#  'impacts': {},
#  'is_downloadable': True,
#  'is_failed': False,
#  'jurisdiction': ['001'],
#  'language': 'en',
#  'lca_discussion': '\n'
#                    '\n'
#                    '## Product Component Notes\n'
#                    'crushed aggregate (ASTM C33), Portland cement (ASTM C150), '
#                    'natural aggregate (ASTM C33), fly ash (ASTM C618), '
#                    'admixture (ASTM C494), batch water (ASTM C1602)\n'
#                    '\n'
#                    '## LCA Notes\n'
#                    'Transportation: Transportation of these materials from '
#                    'supplier to the gate\n'
#                    'of the concrete producer.\n'
#                    'Manufacturing (core processes): Energy used to store, '
#                    'batch, mix, and\n'
#                    'distribute the concrete and operate the facility (concrete '
#                    'plant).\n'
#                    'Water use in mixing and distributing concrete.\n'
#                    'A summary of cradle-to-gate life cycle processes excluded '
#                    'from the EPD is as\n'
#                    'follows:\n'
#                    '\n'
#                    'Production, manufacture, and construction of buildings, '
#                    'capital goods, and\n'
#                    'infrastructure.\n'
#                    'Production and manufacture of concrete production '
#                    'equipment, concrete\n'
#                    'delivery vehicles, earthmoving equipment, and laboratory '
#                    'equipment.\n'
#                    'Personnel-related activities (travel, furniture, office '
#                    'supplies).\n'
#                    'Energy and water use related to company management and '
#                    'sales\n'
#                    'activities.\n'
#                    'A summary of the limitations of this EPD include the '
#                    'following:\n'
#                    '\n'
#                    'This EPD does not report all of the environmental impacts '
#                    'due to\n'
#                    'manufacturing of the product, but rather environmental '
#                    'impacts for\n'
#                    'categories with established LCA-based methods to track and '
#                    'report.\n'
#                    'Unreported environmental impacts include (but are not '
#                    'limited to) factors\n'
#                    'attributable to human health, land use change, water use '
#                    'in the upstream\n'
#                    'manufacturing process, and habitat destruction.\n'
#                    'This EPD reports the results of an LCA for '
#                    '‘cradle-to-gate’ analysis. Thus,\n'
#                    'declarations themselves are not comparative assertions, '
#                    'defined as an\n'
#                    'environmental claim regarding the superiority or '
#                    'equivalence of one\n'
#                    'product versus a competing product that performs the same '
#                    'function. An\n'
#                    'EPD does not make any statements that the product covered '
#                    'by the EPD\n'
#                    'is better or worse than any other product.\n'
#                    'In order to assess the local impacts of product '
#                    'manufacturing, additional\n'
#                    'analysis is required.\n'
#                    'Life cycle impact assessment results are relative '
#                    'expressions and do not\n'
#                    'predict impacts on category endpoints, the exceeding of '
#                    'thresholds,\n'
#                    'safety margins, or risks.\n'
#                    'Note: The product manufacturer has the option of declaring '
#                    'additional information\n'
#                    'about their product including conformance with any other '
#                    'sustainability certification\n'
#                    'programs that often have performance and prescriptive '
#                    'requirements that aim to\n'
#                    'illustrate environmental best practices that cannot be '
#                    'captured by LCA.\n'
#                    '\n'
#                    'Data quality, variability, and comparability\n'
#                    '\n'
#                    'This EPD was created using plant-specific data for '
#                    'upstream materials. Potential\n'
#                    'variations due to supplier locations, manufacturing '
#                    'processes, and efficiencies and\n'
#                    'fuel use are thus accounted for in this EPD. EPDs of '
#                    'concrete mixtures may not be\n'
#                    'comparable if they do not comply with this standard and '
#                    'data from this EPD. While\n'
#                    'EPDs can be used to compare concrete mixes, the data '
#                    'cannot be used to compare\n'
#                    'between construction products or concrete mixes used in '
#                    'different concrete products\n'
#                    'unless the data is integrated into a comprehensive LCA. '
#                    'For example, precast\n'
#                    'concrete, concrete masonry units, and site-cast concrete '
#                    'all have different\n'
#                    'manufacturing processes whose impacts are attributed to '
#                    'different LCA stages. This\n'
#                    'precludes direct comparison between mixes used in these '
#                    'different products until all\n'
#                    'life cycle phases are included.\n'
#                    '\n'
#                    '## Source Data Notes\n'
#                    'Portland cement: Portland Concrete Association, Industry '
#                    'Average EPD,\n'
#                    '2016\n'
#                    'Slag cement: Slag Cement Association, industry average '
#                    'EPD, 2014\n'
#                    'Fly ash: byproduct of  coal combustion; no upstream '
#                    'manufacturing\n'
#                    'impacts\n'
#                    'Silica fume: byproduct of  silicon and ferrosilicon alloy '
#                    'production; no\n'
#                    'upstream manufacturing impacts\n'
#                    'Aggregate (natural): US-EI: “Gravel, round, at mine/US”, '
#                    '2001\n'
#                    'Aggregate (crushed): US-EI process: “Gravel, crushed, at '
#                    'mine/US”,\n'
#                    '2001\n'
#                    'Aggregate (lightweight): custom process, based on US-EI '
#                    'process:\n'
#                    '“Expanded clay, at plant/US”, 2000\n'
#                    'Aggregate (recycled concrete): custom process, based on '
#                    'US-EI\n'
#                    '“Gravel, crushed, at mine/US”, 2001\n'
#                    'Admixture (accelerating): EFCA EPD, “300 ETG '
#                    'AcceleratorEPD”,\n'
#                    'Europe, 2006\n'
#                    'Admixture (air-entraining): EFCA EPD, “301 ETG Air '
#                    'Entrainer EPD”,\n'
#                    'Europe 2006\n'
#                    'Admixture (retarding): EFCA EPD, “302 ETG Retarding EPD”, '
#                    'Europe,\n'
#                    '2006\n'
#                    'Admixture (waterproofing): EFCA EPD, “303 ETG Waterproof '
#                    'ing EPD”,\n'
#                    'Europe, 2006\n'
#                    'Admixture (plasticizing): EFCA EPD, “324 ETG Plasticiser '
#                    'EPD”, Europe,\n'
#                    '2006\n'
#                    'Admixture (superplasticizing): EFCA EPD, “325 ETG '
#                    'Superplasticiser\n'
#                    'EPD”, Europe, 2006\n'
#                    'Admixture (other): Highest impact in each impact category '
#                    'of  the six\n'
#                    'EFCA admixture EPDs, 2006\n'
#                    'Microfibers: ELCD: “Polypropylene f ibres (PP), crude oil '
#                    'based,\n'
#                    'production mix, at plant, PP granulate without additives '
#                    'EU-27 S”, 2005\n'
#                    'Pigments: US-IO process: “Synthetic dye and pigment '
#                    'manufacturing”\n'
#                    'adjusted for inf lation. 2002\n'
#                    'Municipal Water: US-EI process: “Tap water, at user/US”, '
#                    '2000\n'
#                    'Truck transport: US-EI: “Transport, single unit truck, '
#                    'diesel\n'
#                    'powered/NREL/US”, 2007 and US EPA emission factors, 2014\n'
#                    'Rail transport: US-EI: “Transport, train, diesel powered '
#                    'NREL/US”, 2007\n'
#                    'Ship transport: US-EI: “Transport, ocean freighter, '
#                    'average fuel mix\n'
#                    'NREL/US”, 2007\n'
#                    'Diesel: US-EI: “Diesel, combusted in industrial '
#                    'equipment/NREL/US”, 2007\n'
#                    'Natural gas: US-EI: “Natural gas, combusted in industrial\n'
#                    'boiler/NREL/US”, 2007\n'
#                    'Propane: US-EI: “Liquef ied petroleum gas, at ref '
#                    'inery/NREL/US”, 2007,\n'
#                    'and US EPA emission factors, 2008\n'
#                    'Electricity (ASCC): Ecoinvent 3.2: “Electricity, medium '
#                    'voltage, market\n'
#                    'for, Alloc Rec”, 2012\n'
#                    'Electricity (FRCC): Ecoinvent 3.2: “Electricity, medium '
#                    'voltage, market\n'
#                    'for, Alloc Rec”, 2012\n'
#                    'Electricity (HICC): Ecoinvent 3.2: “Electricity, medium '
#                    'voltage, market\n'
#                    'for, Alloc Rec”, 2012\n'
#                    'Electricity (MRO): Ecoinvent 3.2: “Electricity, medium '
#                    'voltage, market\n'
#                    'for, Alloc Rec”, 2012\n'
#                    'Electricity (NPCC): Ecoinvent 3.2: “Electricity, medium '
#                    'voltage, market\n'
#                    'for, Alloc Rec”, 2012\n'
#                    'Electricity (RFC): Ecoinvent 3.2: “Electricity, medium '
#                    'voltage, market for,\n'
#                    'Alloc Rec”, 2012\n'
#                    'Electricity (SERC): Ecoinvent 3.2: “Electricity, medium '
#                    'voltage, market\n'
#                    'for, Alloc Rec”, 2012\n'
#                    'Electricity (SPP): Ecoinvent 3.2: “Electricity, medium '
#                    'voltage, market for,\n'
#                    'Alloc Rec”, 2012\n'
#                    'Electricity (TRE): Ecoinvent 3.2: “Electricity, medium '
#                    'voltage, market for,\n'
#                    'Alloc Rec”, 2012\n'
#                    'Electricity (WECC): Ecoinvent 3.2: “Electricity, medium '
#                    'voltage, market\n'
#                    'for, Alloc Rec”, 2012',
#  'lightweight': True,
#  'manufacturer': {'address': '755 Stockton Avenue, San Jose, CA 95126',
#                   'address_line': '755 Stockton Avenue',
#                   'admin_district': 'CA',
#                   'admin_district2': 'Santa Clara',
#                   'alt_names': ['Central Concrete',
#                                 'Monumental Concrete',
#                                 'Centre Concrete'],
#                   'attachments': {'TransparencyCatalogURL': 'https://www.transparencycatalog.com/company/central-concrete'},
#                   'country': 'US',
#                   'cqd_sync_unlocked': True,
#                   'created_on': '2018-06-21T14:55:59.965541Z',
#                   'email_extensions': ['centralconcrete.com'],
#                   'enterprise': True,
#                   'id': 'c3d7d8d1e466457798d8c37c0df44cee',
#                   'image': 'https://cqddatastore.blob.core.windows.net/cqd/images/baee2a14-dfb9-4e9a-b1b7-f14134e3689b.png',
#                   'latitude': 37.34156,
#                   'legal_name': 'CENTRAL CONCRETE Supply Company',
#                   'locality': 'San Jose',
#                   'location': {'country': 'United States Of America',
#                                'countryCode': 'US',
#                                'countryCodeISO3': 'USA',
#                                'countrySecondarySubdivision': 'Santa Clara',
#                                'countrySubdivision': 'CA',
#                                'countrySubdivisionName': 'California',
#                                'countryTertiarySubdivision': 'San Jose',
#                                'freeformAddress': '755 Stockton Avenue, San '
#                                                   'Jose, CA 95126',
#                                'municipality': 'San Jose',
#                                'municipalitySubdivision': 'San Jose, College '
#                                                           'Park',
#                                'postalCode': '95126',
#                                'streetName': 'Stockton Avenue',
#                                'streetNumber': '755'},
#                   'longitude': -121.91509,
#                   'name': 'Central Concrete',
#                   'org_type': 'Private',
#                   'original_ec3_link': 'https://buildingtransparency.org/ec3/organizations/c3d7d8d1e466457798d8c37c0df44cee',
#                   'password_login_allowed': True,
#                   'pilot_all_employees': False,
#                   'postal_code': '95126',
#                   'primary_activity_builder': False,
#                   'primary_activity_design': False,
#                   'primary_activity_digitization_qa': False,
#                   'primary_activity_education': False,
#                   'primary_activity_forest_practices_certification': False,
#                   'primary_activity_industry_association': False,
#                   'primary_activity_manufacturer': True,
#                   'primary_activity_operator': False,
#                   'primary_activity_other': False,
#                   'primary_activity_owner': False,
#                   'primary_activity_performance_standards_issuer': False,
#                   'primary_activity_sustainability_consulting': False,
#                   'primary_activity_verifier': False,
#                   'updated_on': '2021-04-20T03:01:11.145587Z',
#                   'web_domain': 'centralconcrete.com',
#                   'website': 'http://www.centralconcrete.com/'},
#  'manufacturer_specific': True,
#  'mass_per_declared_unit': '2400 kg',
#  'matched_plants_count': 0,
#  'material_id': 'dea43ddf9107426e8b165acd80a36694',
#  'my_capabilities': 1,
#  'name': 'Mix R751LBE7',
#  'not_an_epd': False,
#  'open_xpd_uuid': 'ec3ae51g',
#  'original_ec3_link': 'https://buildingtransparency.org/ec3/epds/ec3ae51g',
#  'output_flows': {},
#  'pcr': {'alt_names': ['Product Category Rules (PCR) for ISO 14025:2006 Type '
#                        'III Environmental Product Declarations (EPDs) of '
#                        'Concrete',
#                        'North American Product Category Rules (PCR) for ISO '
#                        '14025 Type III Environmental Product Declarations '
#                        '(EPDs) and/or GHG Protocol Conformant Product '
#                        'â€˜Carbon Footprintâ€™ of Concrete',
#                        'North American Product Category Rules v1 (PCR) for ISO '
#                        '14025 Type III Environmental Product Declarations '
#                        '(EPDs) and/or GHG Protocol Conformant Product '
#                        'â€˜Carbon Footprintâ€™ of Concrete',
#                        'Product Category Rules (PCR) for ISO 14025 Type III '
#                        'Environmental Product Declarations (EPDs) Concrete '
#                        'Version 1.1',
#                        'CLF PCR for ISO14025 Type III Environmental Product '
#                        'Declarations for Concrete meeting hte requirement of '
#                        'one of the following:  C90, ASTM C90, CSA A23.1/A23.2, '
#                        'UNSPC code 30111500, Version 1.1, Dec 4, 2013 '
#                        'Clarifications 1,2, and 3',
#                        'PCR for ISO 14025:2006 Type III EPD of Concrete',
#                        'Carbon Leadership Forum (CLF) Product Category Rules '
#                        '(PCR) for ISO 14025 Type III Environmental Product '
#                        'Declarations (EPDs) for Concrete v1.1 (December 2013)',
#                        'The Carbon Leadership Forum PCR: PCR for ISO 14025 '
#                        'Type III EPD for Concrete',
#                        '""The Carbon Leadership Forum PCR: Product Category '
#                        'Rules (PCR) for ISO 14025 Type III Environmental '
#                        'Product Declarations (EPDs) for Concrete, Version 1.1 '
#                        'dated 12/4/2013, serves as the PCR for this EPD. '
#                        'http://www.carbonleadershipforum.org""'],
#          'categories': [],
#          'cqd_sync_unlocked': True,
#          'created_on': '2019-10-07T15:56:48.524245Z',
#          'date_of_issue': '2013-12-04',
#          'date_validity_ends': '2018-12-04',
#          'declared_units': ['1 m3'],
#          'doc': 'https://app.box.com/file/292552692203',
#          'id': '64e661dd8d894db3a1bb327f08edae1f',
#          'lcia_requirements': {'TRACI 2.1': {'order': 1}},
#          'name': 'North American PCR for Concrete',
#          'open_xpd_uuid': 'ec37zjz1',
#          'original_ec3_link': 'https://buildingtransparency.org/ec3/pcrs/ec37zjz1',
#          'requires_mass': False,
#          'requires_uncertainty': False,
#          'short_link': 'cqd.io/p/ec37zjz1ws',
#          'short_name': 'Concrete',
#          'status': 'Expired',
#          'updated_on': '2022-06-24T09:30:38.975464Z',
#          'version': '1.1'},
#  'pct80_gwp_per_category_declared_unit': '479.7960505 kgCO2e',
#  'plant_geography': ['US-CA'],
#  'plant_or_group': {'address': '450 Amador Street, San Francisco, CA 94124',
#                     'address_line': '450 Amador Street',
#                     'admin_district': 'CA',
#                     'admin_district2': 'San Francisco',
#                     'alt_names': ['San Francisco Plant 30'],
#                     'carbon_intensity': '498.686 lbCO2eq/MWh',
#                     'categories': [],
#                     'country': 'US',
#                     'cqd_sync_unlocked': True,
#                     'created_on': '2019-06-03T13:38:06.523288Z',
#                     'id': '0ca8fc5c8925487cabc43b7f6dd7bb20',
#                     'latitude': 37.74614,
#                     'locality': 'San Francisco',
#                     'location': {'country': 'United States',
#                                  'countryCode': 'US',
#                                  'countryCodeISO3': 'USA',
#                                  'countrySecondarySubdivision': 'San Francisco',
#                                  'countrySubdivision': 'CA',
#                                  'countrySubdivisionName': 'California',
#                                  'countryTertiarySubdivision': 'San Francisco',
#                                  'extendedPostalCode': '941241248',
#                                  'freeformAddress': '450 Amador Street, San '
#                                                     'Francisco, CA 94124',
#                                  'localName': 'San Francisco',
#                                  'municipality': 'San Francisco',
#                                  'municipalitySubdivision': 'Bayview',
#                                  'postalCode': '94124',
#                                  'streetName': 'Amador Street',
#                                  'streetNumber': '450'},
#                     'longitude': -122.37916,
#                     'name': 'Bode',
#                     'openepd_id': '849VPJWC+F8.centralconcrete.com',
#                     'owned_by': {'address': '755 Stockton Avenue, San Jose, CA '
#                                             '95126',
#                                  'address_line': '755 Stockton Avenue',
#                                  'admin_district': 'CA',
#                                  'admin_district2': 'Santa Clara',
#                                  'alt_names': ['Central Concrete',
#                                                'Monumental Concrete',
#                                                'Centre Concrete'],
#                                  'attachments': {'TransparencyCatalogURL': 'https://www.transparencycatalog.com/company/central-concrete'},
#                                  'country': 'US',
#                                  'cqd_sync_unlocked': True,
#                                  'created_on': '2018-06-21T14:55:59.965541Z',
#                                  'email_extensions': ['centralconcrete.com'],
#                                  'enterprise': True,
#                                  'id': 'c3d7d8d1e466457798d8c37c0df44cee',
#                                  'image': 'https://cqddatastore.blob.core.windows.net/cqd/images/baee2a14-dfb9-4e9a-b1b7-f14134e3689b.png',
#                                  'latitude': 37.34156,
#                                  'legal_name': 'CENTRAL CONCRETE Supply '
#                                                'Company',
#                                  'locality': 'San Jose',
#                                  'location': {'country': 'United States Of '
#                                                          'America',
#                                               'countryCode': 'US',
#                                               'countryCodeISO3': 'USA',
#                                               'countrySecondarySubdivision': 'Santa '
#                                                                              'Clara',
#                                               'countrySubdivision': 'CA',
#                                               'countrySubdivisionName': 'California',
#                                               'countryTertiarySubdivision': 'San '
#                                                                             'Jose',
#                                               'freeformAddress': '755 Stockton '
#                                                                  'Avenue, San '
#                                                                  'Jose, CA '
#                                                                  '95126',
#                                               'municipality': 'San Jose',
#                                               'municipalitySubdivision': 'San '
#                                                                          'Jose, '
#                                                                          'College '
#                                                                          'Park',
#                                               'postalCode': '95126',
#                                               'streetName': 'Stockton Avenue',
#                                               'streetNumber': '755'},
#                                  'longitude': -121.91509,
#                                  'name': 'Central Concrete',
#                                  'org_type': 'Private',
#                                  'original_ec3_link': 'https://buildingtransparency.org/ec3/organizations/c3d7d8d1e466457798d8c37c0df44cee',
#                                  'password_login_allowed': True,
#                                  'pilot_all_employees': False,
#                                  'postal_code': '95126',
#                                  'primary_activity_builder': False,
#                                  'primary_activity_design': False,
#                                  'primary_activity_digitization_qa': False,
#                                  'primary_activity_education': False,
#                                  'primary_activity_forest_practices_certification': False,
#                                  'primary_activity_industry_association': False,
#                                  'primary_activity_manufacturer': True,
#                                  'primary_activity_operator': False,
#                                  'primary_activity_other': False,
#                                  'primary_activity_owner': False,
#                                  'primary_activity_performance_standards_issuer': False,
#                                  'primary_activity_sustainability_consulting': False,
#                                  'primary_activity_verifier': False,
#                                  'updated_on': '2021-04-20T03:01:11.145587Z',
#                                  'web_domain': 'centralconcrete.com',
#                                  'website': 'http://www.centralconcrete.com/'},
#                     'postal_code': '94124',
#                     'total_epds': 1742,
#                     'type': 'Plant',
#                     'units': 'SI',
#                     'updated_on': '2021-02-01T15:04:55.165646Z'},
#  'plant_specific': True,
#  'plc': False,
#  'private': False,
#  'product_specific': True,
#  'program_operator': {'address': '10857 98th Place Southwest, Vashon, WA 98070',
#                       'address_line': '10857 98th Place Southwest',
#                       'admin_district': 'WA',
#                       'admin_district2': 'King',
#                       'alt_names': ['Earthsure',
#                                     'IERE',
#                                     'Institute for Environmental Research and '
#                                     'Education'],
#                       'country': 'US',
#                       'cqd_sync_unlocked': True,
#                       'created_on': '2018-07-26T13:26:41.418139Z',
#                       'email_extensions': ['iere.org'],
#                       'enterprise': True,
#                       'id': '5609a6ef730f45d381c0dfcc8f1e4030',
#                       'image': 'https://cqddatastore.blob.core.windows.net/cqd/images/09578c87-ff1e-4bef-b9de-710d039dda6c.png',
#                       'invalid_after': '2018-07-01',
#                       'latitude': 47.447029,
#                       'legal_name': 'EarthSure',
#                       'locality': 'Vashon',
#                       'location': {'boundingBox': {'entity': 'position',
#                                                    'northEast': '47.447447,-122.459782',
#                                                    'southWest': '47.446493,-122.459807'},
#                                    'buildingNumber': '10857',
#                                    'country': 'United States',
#                                    'countryCode': 'US',
#                                    'countryCodeISO3': 'USA',
#                                    'countrySecondarySubdivision': 'King',
#                                    'countrySubdivision': 'WA',
#                                    'countrySubdivisionName': 'Washington',
#                                    'countryTertiarySubdivision': 'Vashon '
#                                                                  'Island',
#                                    'freeformAddress': '10857 98th Place '
#                                                       'Southwest, Vashon, WA '
#                                                       '98070',
#                                    'municipality': 'Vashon',
#                                    'municipalitySubdivision': 'Vashon',
#                                    'postalCode': '98070',
#                                    'routeNumbers': [],
#                                    'street': '98th Place Southwest',
#                                    'streetName': '98th Place Southwest',
#                                    'streetNameAndNumber': '10857 98th Place '
#                                                           'Southwest',
#                                    'streetNumber': '10857'},
#                       'longitude': -122.459793,
#                       'name': 'EarthSure',
#                       'org_type': 'Private',
#                       'original_ec3_link': 'https://buildingtransparency.org/ec3/organizations/5609a6ef730f45d381c0dfcc8f1e4030',
#                       'password_login_allowed': True,
#                       'pilot_all_employees': False,
#                       'postal_code': '98070',
#                       'primary_activity_builder': False,
#                       'primary_activity_design': False,
#                       'primary_activity_digitization_qa': False,
#                       'primary_activity_education': False,
#                       'primary_activity_forest_practices_certification': False,
#                       'primary_activity_industry_association': False,
#                       'primary_activity_manufacturer': False,
#                       'primary_activity_operator': True,
#                       'primary_activity_other': False,
#                       'primary_activity_owner': False,
#                       'primary_activity_performance_standards_issuer': False,
#                       'primary_activity_sustainability_consulting': False,
#                       'primary_activity_verifier': True,
#                       'updated_on': '2021-04-20T03:01:11.219477Z',
#                       'web_domain': 'iere.org',
#                       'website': 'http://iere.org/programs/earthsure/'},
#  'program_operator_fkey': '',
#  'resource_uses': {},
#  'reviewer': {'org': {'address': '130 East Randolph Street, Chicago, IL 60601',
#                       'address_line': '130 East Randolph Street',
#                       'admin_district': 'IL',
#                       'admin_district2': 'Cook',
#                       'alt_names': ['PE International',
#                                     'thinkstep, Inc.',
#                                     'thinkstep AG',
#                                     'thinkstep',
#                                     'PE INTERNATIONAL AG',
#                                     'Thinkstep AG'],
#                       'country': 'US',
#                       'cqd_sync_unlocked': True,
#                       'created_on': '2018-09-28T21:38:04.012143Z',
#                       'email': 'info@thinkstep.com',
#                       'email_extensions': ['thinkstep.com',
#                                            'pe-international.com',
#                                            'sphera.com'],
#                       'enterprise': True,
#                       'id': '72d41d92d6d741f68ce626557efcc1c0',
#                       'image': 'https://cqddatastore.blob.core.windows.net/cqd/images/a82275ae-15d5-4a2f-a24f-5a33d97cdcf2',
#                       'latitude': 41.88507,
#                       'legal_name': 'Sphera',
#                       'locality': 'Chicago',
#                       'location': {'country': 'United States',
#                                    'countryCode': 'US',
#                                    'countryCodeISO3': 'USA',
#                                    'countrySecondarySubdivision': 'Cook',
#                                    'countrySubdivision': 'IL',
#                                    'countrySubdivisionName': 'Illinois',
#                                    'countryTertiarySubdivision': 'Chicago',
#                                    'extendedPostalCode': '606016208',
#                                    'freeformAddress': '130 East Randolph '
#                                                       'Street, Chicago, IL '
#                                                       '60601',
#                                    'localName': 'Chicago',
#                                    'municipality': 'Chicago',
#                                    'municipalitySubdivision': 'Downtown '
#                                                               'Chicago',
#                                    'postalCode': '60601',
#                                    'streetName': 'East Randolph Street',
#                                    'streetNumber': '130'},
#                       'longitude': -87.62311,
#                       'name': 'Sphera',
#                       'org_type': 'Private',
#                       'original_ec3_link': 'https://buildingtransparency.org/ec3/organizations/72d41d92d6d741f68ce626557efcc1c0',
#                       'password_login_allowed': True,
#                       'pilot_all_employees': False,
#                       'postal_code': '60601',
#                       'primary_activity_builder': False,
#                       'primary_activity_design': False,
#                       'primary_activity_digitization_qa': False,
#                       'primary_activity_education': False,
#                       'primary_activity_forest_practices_certification': False,
#                       'primary_activity_industry_association': False,
#                       'primary_activity_manufacturer': False,
#                       'primary_activity_operator': False,
#                       'primary_activity_other': True,
#                       'primary_activity_owner': False,
#                       'primary_activity_performance_standards_issuer': False,
#                       'primary_activity_sustainability_consulting': True,
#                       'primary_activity_verifier': True,
#                       'updated_on': '2022-02-02T15:47:47.511452Z',
#                       'web_domain': 'sphera.com',
#                       'website': 'sphera.com'}},
#  'sanitizable': False,
#  'short_link': 'cqd.io/e/ec3ae51gdy',
#  'standard_deviation': '49.10902676 kgCO2e',
#  'stored_carbon_z': 0.2,
#  'supply_chain_specific': 0.0,
#  'updated_on': '2022-12-14T04:17:25.902754Z',
#  'use_stored_carbon': False,
#  'verifier': {'email': 'rita@iere.org',
#               'name': 'Rita Schenck',
#               'org': {'address': '10857 98th Place Southwest, Vashon, WA 98070',
#                       'address_line': '10857 98th Place Southwest',
#                       'admin_district': 'WA',
#                       'admin_district2': 'King',
#                       'alt_names': ['Earthsure',
#                                     'IERE',
#                                     'Institute for Environmental Research and '
#                                     'Education'],
#                       'country': 'US',
#                       'cqd_sync_unlocked': True,
#                       'created_on': '2018-07-26T13:26:41.418139Z',
#                       'email_extensions': ['iere.org'],
#                       'enterprise': True,
#                       'id': '5609a6ef730f45d381c0dfcc8f1e4030',
#                       'image': 'https://cqddatastore.blob.core.windows.net/cqd/images/09578c87-ff1e-4bef-b9de-710d039dda6c.png',
#                       'invalid_after': '2018-07-01',
#                       'latitude': 47.447029,
#                       'legal_name': 'EarthSure',
#                       'locality': 'Vashon',
#                       'location': {'boundingBox': {'entity': 'position',
#                                                    'northEast': '47.447447,-122.459782',
#                                                    'southWest': '47.446493,-122.459807'},
#                                    'buildingNumber': '10857',
#                                    'country': 'United States',
#                                    'countryCode': 'US',
#                                    'countryCodeISO3': 'USA',
#                                    'countrySecondarySubdivision': 'King',
#                                    'countrySubdivision': 'WA',
#                                    'countrySubdivisionName': 'Washington',
#                                    'countryTertiarySubdivision': 'Vashon '
#                                                                  'Island',
#                                    'freeformAddress': '10857 98th Place '
#                                                       'Southwest, Vashon, WA '
#                                                       '98070',
#                                    'municipality': 'Vashon',
#                                    'municipalitySubdivision': 'Vashon',
#                                    'postalCode': '98070',
#                                    'routeNumbers': [],
#                                    'street': '98th Place Southwest',
#                                    'streetName': '98th Place Southwest',
#                                    'streetNameAndNumber': '10857 98th Place '
#                                                           'Southwest',
#                                    'streetNumber': '10857'},
#                       'longitude': -122.459793,
#                       'name': 'EarthSure',
#                       'org_type': 'Private',
#                       'original_ec3_link': 'https://buildingtransparency.org/ec3/organizations/5609a6ef730f45d381c0dfcc8f1e4030',
#                       'password_login_allowed': True,
#                       'pilot_all_employees': False,
#                       'postal_code': '98070',
#                       'primary_activity_builder': False,
#                       'primary_activity_design': False,
#                       'primary_activity_digitization_qa': False,
#                       'primary_activity_education': False,
#                       'primary_activity_forest_practices_certification': False,
#                       'primary_activity_industry_association': False,
#                       'primary_activity_manufacturer': False,
#                       'primary_activity_operator': True,
#                       'primary_activity_other': False,
#                       'primary_activity_owner': False,
#                       'primary_activity_performance_standards_issuer': False,
#                       'primary_activity_sustainability_consulting': False,
#                       'primary_activity_verifier': True,
#                       'updated_on': '2021-04-20T03:01:11.219477Z',
#                       'web_domain': 'iere.org',
#                       'website': 'http://iere.org/programs/earthsure/'}},
#  'warnings': {'concrete_aggregate_size_max': ['Not specified'],
#               'concrete_cement_content': ['Not specified'],
#               'concrete_max_slump': ['Not specified'],
#               'concrete_min_pipeline_size': ['Not specified'],
#               'concrete_min_slump': ['Not specified'],
#               'concrete_slump': ['Not specified'],
#               'concrete_w_c_ratio': ['Not specified'],
#               'impacts': ['EP-FRESH impact not specified',
#                           'EP-TERRESTRIAL impact not specified']},
#  'white_cement': False}

# %%
#Getting material records example
from ec3 import EC3Materials
ec3_materials = EC3Materials(bearer_token=token, ssl_verify=False)

mat_param_dict = {"lightweight":True, "concrete_compressive_strength_at_28d__target":"5000 psi", "jurisdiction":"US"} #Dictonary of params and values. See EC3 Api documentation for options.

ec3_materials.return_fields = ["id", "concrete_compressive_strength_28d", "gwp"] #This can be used to limit the fields beings returned
ec3_materials.sort_by = "concrete_compressive_strength_28d" #This will sort the responses based on the field assiged to the 'sort_by' property

mat_records = ec3_materials.get_materials(return_all=True, params=mat_param_dict) #Setting return_all to True will ignore the max_records number and attempt to return all matches

pprint(mat_records[0])
# Out:
# {'concrete_compressive_strength_28d': '31.02640781925763 MPa',
#  'gwp': '555 kgCO2e',
#  'id': '2720739f950c49978791c97e9fe29762'}

# %%
#Get an epd by xpd uuid
epd_xpd_uuid = "ec3ftbxgp9"

epd_record = ec3_epds.get_epd_by_xpduuid(epd_xpd_uuid)
pprint(epd_record[0])
# Out:
# {'also_shown_in': [],
#  'applicable_in': ['001'],
#  'best_practice': '306.2832727 kgCO2e',
#  'biogenic_embodied_carbon_z': 0.11237437430304116,
#  'box_id': '751413464508',
#  'category': {'allows_any_declared_unit': False,
#               'beta_only': False,
#               'category_statistics_warning': False,
#               'created_on': '2018-06-26T01:11:48.938840Z',
#               'declared_unit': '1 m3',
#               'default_distance': '51.49888 km',
#               'default_transport_mode': 'concrete mixer truck',
#               'description': 'Concretes to be mixed and then poured on-site',
#               'display_name': 'ReadyMix',
#               'draft': False,
#               'facility_type': 'PLANT',
#               'generic_material': False,
#               'hide_service_life': True,
#               'id': 'b03dba1dca5b49acb1a5aa4daab546b4',
#               'includes_b1_stage': False,
#               'lcia_uncertainty': 0.03,
#               'mass_per_declared_unit': '2400 kg',
#               'massless': False,
#               'masterformat': '03 30 00 Cast-in-Place Concrete',
#               'name': 'ReadyMix',
#               'obsolete': False,
#               'openepd': 'Concrete >> ReadyMix',
#               'openepd_name': 'Concrete >> ReadyMix',
#               'pct10_gwp': '261.4406408 kgCO2e',
#               'pct20_gwp': '297.4954762 kgCO2e',
#               'pct30_gwp': '325.3440785 kgCO2e',
#               'pct40_gwp': '350.0109544 kgCO2e',
#               'pct50_gwp': '375.7589206 kgCO2e',
#               'pct60_gwp': '403.8301012 kgCO2e',
#               'pct70_gwp': '434.3809482 kgCO2e',
#               'pct80_gwp': '470.1229563 kgCO2e',
#               'pct90_gwp': '523.090059 kgCO2e',
#               'requires_mass_per_declared_unit': False,
#               'short_name': 'ReadyMix',
#               'short_service_life_disclaimer': False,
#               'unspsc': '30111505',
#               'updated_on': '2023-01-08T07:00:46.509517Z',
#               'use_stored_carbon': 'ABSENT'},
#  'cementitious': {'fly_ash': 0.15},
#  'concrete_aggregate_size_max': '0.75 in',
#  'concrete_air_entrain': True,
#  'concrete_co2_entrain': False,
#  'concrete_compressive_strength_28d': '20.68427188 MPa',
#  'concrete_max_slump': '5 in',
#  'concrete_min_pipeline_size': '3 in',
#  'concrete_min_slump': '3 in',
#  'concrete_self_consolidating': False,
#  'concrete_slump': '4 in',
#  'confirmable_fields': [],
#  'confirmed_fields': [],
#  'conservative_estimate': '370.5031005 kgCO2e',
#  'cqd_sync_unlocked': True,
#  'created_on': '2020-12-31T14:14:28.609429Z',
#  'date_of_issue': '2019-01-28',
#  'date_validity_ends': '2021-10-04',
#  'declared_unit': '1 m3',
#  'density': '2400 kg/m³',
#  'description': 'DOT MINOR 3/4" 15FA 3-5SL AIR',
#  'developer': {'email': 'laurel.mcewen@climateearth.com',
#                'name': 'Laurel McEwen',
#                'org': {'address': '137 Park Place, Richmond, CA 94801',
#                        'address_line': '137 Park Place',
#                        'admin_district': 'CA',
#                        'admin_district2': 'Contra Costa',
#                        'alt_names': ['Climate Earth, Inc.', 'Climate Earth'],
#                        'country': 'US',
#                        'cqd_sync_unlocked': True,
#                        'created_on': '2018-09-07T12:26:19.155179Z',
#                        'email_extensions': ['climateearth.com'],
#                        'enterprise': True,
#                        'id': '5d43c53212c848d9861a81a4bbd626b2',
#                        'image': 'https://cqddatastore.blob.core.windows.net/cqd/images/7ce922a6-8120-420c-9ca9-cd4ff793d90e',
#                        'latitude': 37.9266,
#                        'legal_name': 'Climate Earth',
#                        'locality': 'Richmond',
#                        'location': {'country': 'United States',
#                                     'countryCode': 'US',
#                                     'countryCodeISO3': 'USA',
#                                     'countrySecondarySubdivision': 'Contra '
#                                                                    'Costa',
#                                     'countrySubdivision': 'CA',
#                                     'countrySubdivisionName': 'California',
#                                     'extendedPostalCode': '948013895',
#                                     'freeformAddress': '137 Park Place, '
#                                                        'Richmond, CA 94801',
#                                     'localName': 'Richmond',
#                                     'municipality': 'Richmond',
#                                     'postalCode': '94801',
#                                     'streetName': 'Park Place',
#                                     'streetNumber': '137'},
#                        'longitude': -122.38494,
#                        'name': 'Climate Earth',
#                        'org_type': 'Private',
#                        'original_ec3_link': 'https://buildingtransparency.org/ec3/organizations/5d43c53212c848d9861a81a4bbd626b2',
#                        'password_login_allowed': True,
#                        'pilot_all_employees': False,
#                        'postal_code': '94801',
#                        'primary_activity_builder': False,
#                        'primary_activity_design': False,
#                        'primary_activity_digitization_qa': False,
#                        'primary_activity_education': False,
#                        'primary_activity_forest_practices_certification': False,
#                        'primary_activity_industry_association': False,
#                        'primary_activity_manufacturer': False,
#                        'primary_activity_operator': True,
#                        'primary_activity_other': False,
#                        'primary_activity_owner': False,
#                        'primary_activity_performance_standards_issuer': False,
#                        'primary_activity_sustainability_consulting': True,
#                        'primary_activity_verifier': True,
#                        'updated_on': '2021-04-20T03:01:07.468332Z',
#                        'web_domain': 'climateearth.com',
#                        'website': 'http://www.climateearth.com'}},
#  'doc': 'cqd.io/e/ec3yznau9d',
#  'epd_degraded': False,
#  'excluded': False,
#  'externally_verified': True,
#  'gwp': '339 kgCO2e',
#  'gwp_per_category_declared_unit': '339 kgCO2e',
#  'gwp_per_kg': '0.14125 kgCO2e',
#  'gwp_z': 0.11237437430304116,
#  'id': 'd58a88bc8dac40d09fc8b47ff94a552d',
#  'impacts': {},
#  'is_downloadable': True,
#  'is_failed': False,
#  'jurisdiction': ['001'],
#  'language': 'en',
#  'lca_discussion': '\n'
#                    '\n'
#                    '## Product Component Notes\n'
#                    'crushed aggregate (ASTM C33), natural aggregate (ASTM '
#                    'C33), Portland cement (ASTM C150), fly ash (ASTM C618), '
#                    'batch water (ASTM C1602), admixture (ASTM C494)\n'
#                    '\n'
#                    '## Source Data Notes\n'
#                    'Portland cement: Portland Concrete Association, Industry '
#                    'Average EPD, 2016 Fly ash: byproduct of coal combustion; '
#                    'no upstream manufacturing impacts Aggregate: Supplier '
#                    'specific primary data, 2018 Aggregate: Supplier specific '
#                    'primary data, 2016 Admixture (waterproofing): EFCA EPD, '
#                    'Europe, 2015 Municipal Water: US-EI (2016): “Tap water, at '
#                    'user/US”, 2000 Truck transport: US-EI (2014): Transport, '
#                    'single unit truck, diesel powered/NREL/US, 2007 and US EPA '
#                    'emission factors, 2014 Rail transport: US-EI (2014): '
#                    'Transport, train, diesel powered NREL/US, 2007 Ship '
#                    'transport: US-EI (2014): Transport, ocean freighter, '
#                    'average fuel mix NREL/US, 2007 Electricity (WECC): '
#                    'Ecoinvent 3.32: “Electricity, medium voltage, market for, '
#                    'Alloc Rec”, 2015 Diesel: US-EI (2016): “Diesel, combusted '
#                    'in industrial equipment/NREL/US”, 2007',
#  'lightweight': False,
#  'manufacturer': {'address': '755 Stockton Avenue, San Jose, CA 95126',
#                   'address_line': '755 Stockton Avenue',
#                   'admin_district': 'CA',
#                   'admin_district2': 'Santa Clara',
#                   'alt_names': ['Central Concrete',
#                                 'Monumental Concrete',
#                                 'Centre Concrete'],
#                   'attachments': {'TransparencyCatalogURL': 'https://www.transparencycatalog.com/company/central-concrete'},
#                   'country': 'US',
#                   'cqd_sync_unlocked': True,
#                   'created_on': '2018-06-21T14:55:59.965541Z',
#                   'email_extensions': ['centralconcrete.com'],
#                   'enterprise': True,
#                   'id': 'c3d7d8d1e466457798d8c37c0df44cee',
#                   'image': 'https://cqddatastore.blob.core.windows.net/cqd/images/baee2a14-dfb9-4e9a-b1b7-f14134e3689b.png',
#                   'latitude': 37.34156,
#                   'legal_name': 'CENTRAL CONCRETE Supply Company',
#                   'locality': 'San Jose',
#                   'location': {'country': 'United States Of America',
#                                'countryCode': 'US',
#                                'countryCodeISO3': 'USA',
#                                'countrySecondarySubdivision': 'Santa Clara',
#                                'countrySubdivision': 'CA',
#                                'countrySubdivisionName': 'California',
#                                'countryTertiarySubdivision': 'San Jose',
#                                'freeformAddress': '755 Stockton Avenue, San '
#                                                   'Jose, CA 95126',
#                                'municipality': 'San Jose',
#                                'municipalitySubdivision': 'San Jose, College '
#                                                           'Park',
#                                'postalCode': '95126',
#                                'streetName': 'Stockton Avenue',
#                                'streetNumber': '755'},
#                   'longitude': -121.91509,
#                   'name': 'Central Concrete',
#                   'org_type': 'Private',
#                   'original_ec3_link': 'https://buildingtransparency.org/ec3/organizations/c3d7d8d1e466457798d8c37c0df44cee',
#                   'password_login_allowed': True,
#                   'pilot_all_employees': False,
#                   'postal_code': '95126',
#                   'primary_activity_builder': False,
#                   'primary_activity_design': False,
#                   'primary_activity_digitization_qa': False,
#                   'primary_activity_education': False,
#                   'primary_activity_forest_practices_certification': False,
#                   'primary_activity_industry_association': False,
#                   'primary_activity_manufacturer': True,
#                   'primary_activity_operator': False,
#                   'primary_activity_other': False,
#                   'primary_activity_owner': False,
#                   'primary_activity_performance_standards_issuer': False,
#                   'primary_activity_sustainability_consulting': False,
#                   'primary_activity_verifier': False,
#                   'updated_on': '2021-04-20T03:01:11.145587Z',
#                   'web_domain': 'centralconcrete.com',
#                   'website': 'http://www.centralconcrete.com/'},
#  'manufacturer_specific': True,
#  'mass_per_declared_unit': '2400 kg',
#  'matched_plants_count': 0,
#  'material_id': '91f7d01b7b5540509e42315637c0cc01',
#  'my_capabilities': 1,
#  'name': 'DM0115CA',
#  'not_an_epd': False,
#  'open_xpd_uuid': 'ec3yznau',
#  'original_ec3_link': 'https://buildingtransparency.org/ec3/epds/ec3yznau',
#  'output_flows': {},
#  'owner': {'name': 'cqd.io Admin',
#            'user_id': 'cqd.admin@buildingtransparency.org'},
#  'pcr': {'alt_names': ['NSF PCR for Concrete',
#                        'ISO 21930:2017 Sustainability in Building Construction '
#                        '- Environmental Declaration of Building Products: '
#                        'serves as the core PCR PCR for Concrete, NSF '
#                        'International, February 2019 serves as the '
#                        'sub-category PCR',
#                        'Product Category Rule for Environmental Product '
#                        'Declarations PCR for Concrete',
#                        'ISO 21930:2017 Sustainability in Building Construction '
#                        '- Environmental Declaration of Building Products '
#                        'serves as the core PCR. NSF International Product '
#                        'Category Rule (PCR) for Concrete Version 1 (February '
#                        '22, 2019) serves as the sub-category PCR'],
#          'categories': [],
#          'cqd_sync_unlocked': True,
#          'created_on': '2019-10-09T11:55:36.295338Z',
#          'date_of_issue': '2019-02-22',
#          'date_validity_ends': '2021-07-31',
#          'declared_units': ['1 m3'],
#          'doc': 'https://www.nrmca.org/wp-content/uploads/2020/02/NSF_PCR_CONCRETE2019.pdf',
#          'id': 'c4d00c85479b42229c8c3e88e1e36366',
#          'lcia_requirements': {'TRACI 2.1': {'impacts': [],
#                                              'jurisdiction': ['001'],
#                                              'order': 1}},
#          'name': 'NSF PCR for Concrete',
#          'open_xpd_uuid': 'ec39kz7y',
#          'original_ec3_link': 'https://buildingtransparency.org/ec3/pcrs/ec39kz7y',
#          'product_classes': {},
#          'requires_mass': False,
#          'requires_uncertainty': False,
#          'short_link': 'cqd.io/p/ec39kz7yt5',
#          'short_name': 'Concrete',
#          'status': 'Expired',
#          'updated_on': '2022-08-19T11:51:31.862318Z',
#          'version': '1'},
#  'pct80_gwp_per_category_declared_unit': '370.5031005 kgCO2e',
#  'plant_geography': ['US-CA'],
#  'plant_or_group': {'address': '457 Queens Lane, San Jose, CA 95112',
#                     'address_line': '457 Queens Lane',
#                     'admin_district': 'CA',
#                     'admin_district2': 'Santa Clara',
#                     'alt_names': [],
#                     'carbon_intensity': '498.686 lbCO2eq/MWh',
#                     'categories': [],
#                     'country': 'US',
#                     'cqd_sync_unlocked': True,
#                     'created_on': '2018-06-21T19:20:12.065963Z',
#                     'id': '1b2875c2355e4438819fe447129e7ce7',
#                     'latitude': 37.37072,
#                     'locality': 'San Jose',
#                     'location': {'country': 'United States Of America',
#                                  'countryCode': 'US',
#                                  'countryCodeISO3': 'USA',
#                                  'countrySecondarySubdivision': 'Santa Clara',
#                                  'countrySubdivision': 'CA',
#                                  'countrySubdivisionName': 'California',
#                                  'countryTertiarySubdivision': 'San Jose',
#                                  'extendedPostalCode': '951124310',
#                                  'freeformAddress': '457 Queens Lane, San '
#                                                     'Jose, CA 95112',
#                                  'localName': 'San Jose',
#                                  'municipality': 'San Jose',
#                                  'municipalitySubdivision': 'San Jose',
#                                  'postalCode': '95112',
#                                  'streetName': 'Queens Lane',
#                                  'streetNumber': '457'},
#                     'longitude': -121.90409,
#                     'name': 'Queens Lane (wet)',
#                     'openepd_id': '849W93CW+79.centralconcrete.com',
#                     'owned_by': {'address': '755 Stockton Avenue, San Jose, CA '
#                                             '95126',
#                                  'address_line': '755 Stockton Avenue',
#                                  'admin_district': 'CA',
#                                  'admin_district2': 'Santa Clara',
#                                  'alt_names': ['Central Concrete',
#                                                'Monumental Concrete',
#                                                'Centre Concrete'],
#                                  'attachments': {'TransparencyCatalogURL': 'https://www.transparencycatalog.com/company/central-concrete'},
#                                  'country': 'US',
#                                  'cqd_sync_unlocked': True,
#                                  'created_on': '2018-06-21T14:55:59.965541Z',
#                                  'email_extensions': ['centralconcrete.com'],
#                                  'enterprise': True,
#                                  'id': 'c3d7d8d1e466457798d8c37c0df44cee',
#                                  'image': 'https://cqddatastore.blob.core.windows.net/cqd/images/baee2a14-dfb9-4e9a-b1b7-f14134e3689b.png',
#                                  'latitude': 37.34156,
#                                  'legal_name': 'CENTRAL CONCRETE Supply '
#                                                'Company',
#                                  'locality': 'San Jose',
#                                  'location': {'country': 'United States Of '
#                                                          'America',
#                                               'countryCode': 'US',
#                                               'countryCodeISO3': 'USA',
#                                               'countrySecondarySubdivision': 'Santa '
#                                                                              'Clara',
#                                               'countrySubdivision': 'CA',
#                                               'countrySubdivisionName': 'California',
#                                               'countryTertiarySubdivision': 'San '
#                                                                             'Jose',
#                                               'freeformAddress': '755 Stockton '
#                                                                  'Avenue, San '
#                                                                  'Jose, CA '
#                                                                  '95126',
#                                               'municipality': 'San Jose',
#                                               'municipalitySubdivision': 'San '
#                                                                          'Jose, '
#                                                                          'College '
#                                                                          'Park',
#                                               'postalCode': '95126',
#                                               'streetName': 'Stockton Avenue',
#                                               'streetNumber': '755'},
#                                  'longitude': -121.91509,
#                                  'name': 'Central Concrete',
#                                  'org_type': 'Private',
#                                  'original_ec3_link': 'https://buildingtransparency.org/ec3/organizations/c3d7d8d1e466457798d8c37c0df44cee',
#                                  'password_login_allowed': True,
#                                  'pilot_all_employees': False,
#                                  'postal_code': '95126',
#                                  'primary_activity_builder': False,
#                                  'primary_activity_design': False,
#                                  'primary_activity_digitization_qa': False,
#                                  'primary_activity_education': False,
#                                  'primary_activity_forest_practices_certification': False,
#                                  'primary_activity_industry_association': False,
#                                  'primary_activity_manufacturer': True,
#                                  'primary_activity_operator': False,
#                                  'primary_activity_other': False,
#                                  'primary_activity_owner': False,
#                                  'primary_activity_performance_standards_issuer': False,
#                                  'primary_activity_sustainability_consulting': False,
#                                  'primary_activity_verifier': False,
#                                  'updated_on': '2021-04-20T03:01:11.145587Z',
#                                  'web_domain': 'centralconcrete.com',
#                                  'website': 'http://www.centralconcrete.com/'},
#                     'postal_code': '95112',
#                     'total_epds': 2651,
#                     'type': 'Plant',
#                     'updated_on': '2020-08-19T10:35:22.490782Z'},
#  'plant_specific': True,
#  'plc': False,
#  'private': False,
#  'product_specific': True,
#  'program_operator': {'address': '100 Barr Harbor Dr, Conshohocken, PA 19428, '
#                                  'USA',
#                       'address_line': '100 Barr Harbor Dr',
#                       'admin_district': 'PA',
#                       'admin_district2': 'Montgomery County',
#                       'alt_names': ['astm', 'ASTMInternational'],
#                       'attachments': {'Programme Instructions': 'https://www.astm.org/CERTIFICATION/DOCS/162.ASTM_General_Program_Instructions_6.0_110414.pdf'},
#                       'country': 'US',
#                       'cqd_sync_unlocked': True,
#                       'created_on': '2018-10-01T05:13:50.328641Z',
#                       'email_extensions': ['astm.org'],
#                       'enterprise': True,
#                       'id': '2657c6a84bfa4675a5e4ee785c253a48',
#                       'image': 'https://cqddatastore.blob.core.windows.net/cqd/images/d2e41902-21b7-486d-b303-d84c4b95ecfc.png',
#                       'latitude': 40.0689574,
#                       'legal_name': 'ASTM International',
#                       'locality': 'Conshohocken',
#                       'location': [{'long_name': '100',
#                                     'short_name': '100',
#                                     'types': ['street_number']},
#                                    {'long_name': 'Barr Harbor Drive',
#                                     'short_name': 'Barr Harbor Dr',
#                                     'types': ['route']},
#                                    {'long_name': 'Conshohocken',
#                                     'short_name': 'Conshohocken',
#                                     'types': ['locality', 'political']},
#                                    {'long_name': 'Montgomery County',
#                                     'short_name': 'Montgomery County',
#                                     'types': ['administrative_area_level_2',
#                                               'political']},
#                                    {'long_name': 'Pennsylvania',
#                                     'short_name': 'PA',
#                                     'types': ['administrative_area_level_1',
#                                               'political']},
#                                    {'long_name': 'United States',
#                                     'short_name': 'US',
#                                     'types': ['country', 'political']},
#                                    {'long_name': '19428',
#                                     'short_name': '19428',
#                                     'types': ['postal_code']},
#                                    {'long_name': '2951',
#                                     'short_name': '2951',
#                                     'types': ['postal_code_suffix']}],
#                       'longitude': -75.3083283,
#                       'name': 'ASTM International',
#                       'org_type': 'Private',
#                       'original_ec3_link': 'https://buildingtransparency.org/ec3/organizations/2657c6a84bfa4675a5e4ee785c253a48',
#                       'password_login_allowed': True,
#                       'pilot_all_employees': False,
#                       'postal_code': '19428',
#                       'primary_activity_builder': False,
#                       'primary_activity_design': False,
#                       'primary_activity_digitization_qa': False,
#                       'primary_activity_education': False,
#                       'primary_activity_forest_practices_certification': False,
#                       'primary_activity_industry_association': False,
#                       'primary_activity_manufacturer': False,
#                       'primary_activity_operator': True,
#                       'primary_activity_other': True,
#                       'primary_activity_owner': False,
#                       'primary_activity_performance_standards_issuer': True,
#                       'primary_activity_sustainability_consulting': False,
#                       'primary_activity_verifier': True,
#                       'updated_on': '2021-12-13T15:59:10.095003Z',
#                       'web_domain': 'astm.org',
#                       'website': 'https://www.astm.org/CERTIFICATION/EpdAndPCRs.html'},
#  'program_operator_fkey': '9BD4F9CB-3584-4D34-90F8-B6E40B69653D',
#  'resource_uses': {},
#  'sanitizable': False,
#  'short_link': 'cqd.io/e/ec3yznau9d',
#  'standard_deviation': '37.9224603 kgCO2e',
#  'stored_carbon_z': 0.2,
#  'supply_chain_specific': 0.0,
#  'updated_on': '2022-09-12T13:55:16.479311Z',
#  'use_stored_carbon': False,
#  'verifier': {'email': 'rita@iere.org',
#               'name': 'Rita Schenck',
#               'org': {'address': '10857 98th Place Southwest, Vashon, WA 98070',
#                       'address_line': '10857 98th Place Southwest',
#                       'admin_district': 'WA',
#                       'admin_district2': 'King',
#                       'alt_names': ['Earthsure',
#                                     'IERE',
#                                     'Institute for Environmental Research and '
#                                     'Education'],
#                       'country': 'US',
#                       'cqd_sync_unlocked': True,
#                       'created_on': '2018-07-26T13:26:41.418139Z',
#                       'email_extensions': ['iere.org'],
#                       'enterprise': True,
#                       'id': '5609a6ef730f45d381c0dfcc8f1e4030',
#                       'image': 'https://cqddatastore.blob.core.windows.net/cqd/images/09578c87-ff1e-4bef-b9de-710d039dda6c.png',
#                       'invalid_after': '2018-07-01',
#                       'latitude': 47.447029,
#                       'legal_name': 'EarthSure',
#                       'locality': 'Vashon',
#                       'location': {'boundingBox': {'entity': 'position',
#                                                    'northEast': '47.447447,-122.459782',
#                                                    'southWest': '47.446493,-122.459807'},
#                                    'buildingNumber': '10857',
#                                    'country': 'United States',
#                                    'countryCode': 'US',
#                                    'countryCodeISO3': 'USA',
#                                    'countrySecondarySubdivision': 'King',
#                                    'countrySubdivision': 'WA',
#                                    'countrySubdivisionName': 'Washington',
#                                    'countryTertiarySubdivision': 'Vashon '
#                                                                  'Island',
#                                    'freeformAddress': '10857 98th Place '
#                                                       'Southwest, Vashon, WA '
#                                                       '98070',
#                                    'municipality': 'Vashon',
#                                    'municipalitySubdivision': 'Vashon',
#                                    'postalCode': '98070',
#                                    'routeNumbers': [],
#                                    'street': '98th Place Southwest',
#                                    'streetName': '98th Place Southwest',
#                                    'streetNameAndNumber': '10857 98th Place '
#                                                           'Southwest',
#                                    'streetNumber': '10857'},
#                       'longitude': -122.459793,
#                       'name': 'EarthSure',
#                       'org_type': 'Private',
#                       'original_ec3_link': 'https://buildingtransparency.org/ec3/organizations/5609a6ef730f45d381c0dfcc8f1e4030',
#                       'password_login_allowed': True,
#                       'pilot_all_employees': False,
#                       'postal_code': '98070',
#                       'primary_activity_builder': False,
#                       'primary_activity_design': False,
#                       'primary_activity_digitization_qa': False,
#                       'primary_activity_education': False,
#                       'primary_activity_forest_practices_certification': False,
#                       'primary_activity_industry_association': False,
#                       'primary_activity_manufacturer': False,
#                       'primary_activity_operator': True,
#                       'primary_activity_other': False,
#                       'primary_activity_owner': False,
#                       'primary_activity_performance_standards_issuer': False,
#                       'primary_activity_sustainability_consulting': False,
#                       'primary_activity_verifier': True,
#                       'updated_on': '2021-04-20T03:01:11.219477Z',
#                       'web_domain': 'iere.org',
#                       'website': 'http://iere.org/programs/earthsure/'}},
#  'warnings': {'concrete_cement_content': ['Not specified'],
#               'concrete_w_c_ratio': ['Not specified'],
#               'impacts': ['EP-FRESH impact not specified',
#                           'EP-TERRESTRIAL impact not specified',
#                           "PCR's required LCIA Method not found in the "
#                           'document']},
#  'white_cement': False}

# %%
#Get an material by the xpd uuid of an epd
mat_record = ec3_materials.get_material_by_xpduuid(epd_xpd_uuid)
pprint(mat_record[0])
# Out:
# {'also_shown_in': [],
#  'applicable_in': ['001'],
#  'best_practice': '0.09956023337 kgCO2e',
#  'biogenic_embodied_carbon_z': 0.2104756517984919,
#  'category': {'allows_any_declared_unit': False,
#               'beta_only': True,
#               'category_statistics_warning': False,
#               'created_on': '2020-08-18T07:57:40Z',
#               'declared_unit': '1 t',
#               'default_distance': '189.90212 km',
#               'default_transport_mode': 'truck, unspecified',
#               'description': 'Cementitious paste used to bind building blocks '
#                              'such as stones, bricks, and concrete masonry.',
#               'display_name': 'Mortar',
#               'draft': False,
#               'facility_type': 'PLANT',
#               'generic_material': False,
#               'hide_service_life': True,
#               'id': 'a3fe7d7744f9466cbb99b64e361888b4',
#               'includes_b1_stage': False,
#               'lcia_uncertainty': 0.03,
#               'mass_per_declared_unit': '1000 kg',
#               'massless': False,
#               'masterformat': '04 05 13 Masonry Mortaring',
#               'name': 'Mortar',
#               'obsolete': False,
#               'openepd': 'Accessories >> Mortar',
#               'openepd_name': 'Accessories >> Mortar',
#               'pct10_gwp': '141.4334034 kgCO2e',
#               'pct20_gwp': '194.4496428 kgCO2e',
#               'pct30_gwp': '248.0665454 kgCO2e',
#               'pct40_gwp': '295.1603128 kgCO2e',
#               'pct50_gwp': '371.1152298 kgCO2e',
#               'pct60_gwp': '449.5442484 kgCO2e',
#               'pct70_gwp': '554.6935635 kgCO2e',
#               'pct80_gwp': '601.5961384 kgCO2e',
#               'pct90_gwp': '864.814321 kgCO2e',
#               'requires_mass_per_declared_unit': False,
#               'short_name': 'Mortar',
#               'short_service_life_disclaimer': False,
#               'updated_on': '2023-01-08T07:02:19.185497Z',
#               'use_stored_carbon': 'ABSENT'},
#  'conservative_estimate': '0.1430192545 kgCO2e',
#  'created_on': '2021-06-15T11:50:06.803883Z',
#  'declared_unit': '1 kg',
#  'description': 'Murmörtel M5, Dry Mortar is a dry mortar based on masonry '
#                 'cement and sand. Mix with water to get a ready-to-use mortar '
#                 'for most indoor and outdoor use. Murmörtel M5, Dry Mortar is '
#                 'well suited for most masonry and rendering work with bricks '
#                 'and light clinker blocks.',
#  'epd_id': '91b77593502941ab81285c60e1640bd2',
#  'errors': {},
#  'failures': {},
#  'gwp': '0.122 kgCO2e',
#  'gwp_per_category_declared_unit': '122 kgCO2e',
#  'gwp_per_kg': '0.122 kgCO2e',
#  'gwp_z': 0.2104756517984919,
#  'id': '78349f81ab4a4c40a9508c65307f343d',
#  'image': 'https://cqddatastore.blob.core.windows.net/cqd/images/88a1e47aaad74a63a690135d0e22e515.png',
#  'industry_standards': ['SO 14001'],
#  'is_downloadable': True,
#  'is_failed': False,
#  'manufacturer': {'address': 'Betongvägen, Finja',
#                   'address_line': ' Betongvägen',
#                   'admin_district': 'Skåne Län',
#                   'country': 'SE',
#                   'cqd_sync_unlocked': True,
#                   'created_on': '2021-01-19T10:42:21.861438Z',
#                   'enterprise': True,
#                   'id': '6909aaae67af484599b88be3504eef5e',
#                   'latitude': 56.17495,
#                   'locality': 'Hässleholm',
#                   'location': {'country': 'Sverige',
#                                'countryCode': 'SE',
#                                'countryCodeISO3': 'SWE',
#                                'countrySubdivision': 'Skåne Län',
#                                'freeformAddress': 'Betongvägen, Finja',
#                                'localName': 'Finja',
#                                'municipality': 'Hässleholm',
#                                'municipalitySubdivision': 'Finja',
#                                'postalCode': '28153, 28193',
#                                'streetName': 'Betongvägen'},
#                   'longitude': 13.70081,
#                   'name': 'Finja Betong AB',
#                   'original_ec3_link': 'https://buildingtransparency.org/ec3/organizations/6909aaae67af484599b88be3504eef5e',
#                   'password_login_allowed': True,
#                   'pilot_all_employees': False,
#                   'postal_code': '28153, 28193',
#                   'primary_activity_builder': False,
#                   'primary_activity_design': False,
#                   'primary_activity_digitization_qa': False,
#                   'primary_activity_education': False,
#                   'primary_activity_forest_practices_certification': False,
#                   'primary_activity_industry_association': False,
#                   'primary_activity_manufacturer': False,
#                   'primary_activity_operator': False,
#                   'primary_activity_other': False,
#                   'primary_activity_owner': False,
#                   'primary_activity_performance_standards_issuer': False,
#                   'primary_activity_sustainability_consulting': False,
#                   'primary_activity_verifier': False,
#                   'updated_on': '2021-04-26T16:46:00.270005Z',
#                   'web_domain': 'finja.se',
#                   'website': 'https://www.finja.se/'},
#  'mass_per_declared_unit': '1 kg',
#  'name': 'Murmörtel M5, Dry Mortar',
#  'open_xpd_uuid': 'ec3pe7nb',
#  'pct80_gwp_per_category_declared_unit': '143.0192545 kgCO2e',
#  'plant_or_group': {'address': 'Betongvägen, 281 53 Finja, Sweden',
#                     'address_line': 'Betongvägen',
#                     'admin_district': 'Skåne län',
#                     'carbon_intensity': '0.079 tCO2e/MWh',
#                     'categories': [],
#                     'country': 'SE',
#                     'cqd_sync_unlocked': True,
#                     'created_on': '2021-02-16T11:08:54.371713Z',
#                     'id': '8b8e1372619b439382c2b376d0e98ba1',
#                     'latitude': 56.1716693,
#                     'location': [{'long_name': 'Betongvägen',
#                                   'short_name': 'Betongvägen',
#                                   'types': ['route']},
#                                  {'long_name': 'Hässleholm S',
#                                   'short_name': 'Hässleholm S',
#                                   'types': ['political',
#                                             'sublocality',
#                                             'sublocality_level_1']},
#                                  {'long_name': 'Finja',
#                                   'short_name': 'Finja',
#                                   'types': ['postal_town']},
#                                  {'long_name': 'Skåne län',
#                                   'short_name': 'Skåne län',
#                                   'types': ['administrative_area_level_1',
#                                             'political']},
#                                  {'long_name': 'Sweden',
#                                   'short_name': 'SE',
#                                   'types': ['country', 'political']},
#                                  {'long_name': '281 53',
#                                   'short_name': '281 53',
#                                   'types': ['postal_code']}],
#                     'longitude': 13.7004503,
#                     'name': 'Finja',
#                     'openepd_id': '9F8M5PC2+M5.finja.se',
#                     'owned_by': {'address': 'Betongvägen, Finja',
#                                  'address_line': ' Betongvägen',
#                                  'admin_district': 'Skåne Län',
#                                  'country': 'SE',
#                                  'cqd_sync_unlocked': True,
#                                  'created_on': '2021-01-19T10:42:21.861438Z',
#                                  'enterprise': True,
#                                  'id': '6909aaae67af484599b88be3504eef5e',
#                                  'latitude': 56.17495,
#                                  'locality': 'Hässleholm',
#                                  'location': {'country': 'Sverige',
#                                               'countryCode': 'SE',
#                                               'countryCodeISO3': 'SWE',
#                                               'countrySubdivision': 'Skåne Län',
#                                               'freeformAddress': 'Betongvägen, '
#                                                                  'Finja',
#                                               'localName': 'Finja',
#                                               'municipality': 'Hässleholm',
#                                               'municipalitySubdivision': 'Finja',
#                                               'postalCode': '28153, 28193',
#                                               'streetName': 'Betongvägen'},
#                                  'longitude': 13.70081,
#                                  'name': 'Finja Betong AB',
#                                  'original_ec3_link': 'https://buildingtransparency.org/ec3/organizations/6909aaae67af484599b88be3504eef5e',
#                                  'password_login_allowed': True,
#                                  'pilot_all_employees': False,
#                                  'postal_code': '28153, 28193',
#                                  'primary_activity_builder': False,
#                                  'primary_activity_design': False,
#                                  'primary_activity_digitization_qa': False,
#                                  'primary_activity_education': False,
#                                  'primary_activity_forest_practices_certification': False,
#                                  'primary_activity_industry_association': False,
#                                  'primary_activity_manufacturer': False,
#                                  'primary_activity_operator': False,
#                                  'primary_activity_other': False,
#                                  'primary_activity_owner': False,
#                                  'primary_activity_performance_standards_issuer': False,
#                                  'primary_activity_sustainability_consulting': False,
#                                  'primary_activity_verifier': False,
#                                  'updated_on': '2021-04-26T16:46:00.270005Z',
#                                  'web_domain': 'finja.se',
#                                  'website': 'https://www.finja.se/'},
#                     'postal_code': '281 53',
#                     'total_epds': 1,
#                     'type': 'Plant',
#                     'units': 'SI',
#                     'updated_on': '2021-02-16T11:08:54.371722Z'},
#  'product_classes': {},
#  'standard_deviation': '0.02595499322 kgCO2e',
#  'stored_carbon_z': 0.2,
#  'updated_on': '2022-05-16T08:29:15.946433Z',
#  'use_stored_carbon': False,
#  'warnings': {'density': ['Not specified'],
#               'impacts': ['EP-MARINE impact not specified',
#                           'EP-TERRESTRIAL impact not specified']}}
